# %% [markdown]
# ### How to Speed up Pandas by 4x

# %%
import pandas as pd

# %% [markdown]
# ## Read in the data with Pandas

# %%
# %%time
df = pd.read_csv("esea_master_dmg_demos.part1.csv")
# Out:
# Wall time: 27.1 s

# %%
#Install                                    #Link: https://modin.readthedocs.io/en/latest/installation.html
#!pip install modin[ray]

# %%
### Read in the data with Modin
import modin.pandas as pd

# %%
import ray
ray.init()
# Out:
# 2021-10-11 08:07:42,048	INFO services.py:1250 -- View the Ray dashboard at http://127.0.0.1:8265
# {'node_ip_address': '192.168.1.16',
#  'raylet_ip_address': '192.168.1.16',
#  'redis_address': '192.168.1.16:6379',
#  'object_store_address': 'tcp://127.0.0.1:64330',
#  'raylet_socket_name': 'tcp://127.0.0.1:63780',
#  'webui_url': '127.0.0.1:8265',
#  'session_dir': 'C:\\Users\\MD550B~1.ATI\\AppData\\Local\\Temp\\ray\\session_2021-10-11_08-07-33_953595_9748',
#  'metrics_export_port': 62052,
#  'node_id': '78f3b7366fba6745ed07bb132ad4d2f2251d55b11c0ecf6855be9952'}

# %%
# %%time
df = pd.read_csv("esea_master_dmg_demos.part1.csv")
# Out:
# Wall time: 19.6 s

# %%
import modin.pandas as pd

# %%
import modin.pandas as pd
import numpy as np

frame_data = np.random.randint(0, 100, size=(2**10, 2**8))
df = pd.DataFrame(frame_data)
# Out:
# UserWarning: Distributing <class 'numpy.ndarray'> object. This may take some time.

# %%
df.shape
# Out:
# (1024, 256)

# %%
df.to_csv('test.csv')

# %%
# %%time
import pandas as pd
pd.read_csv('https://raw.githubusercontent.com/MateLabs/Public-Datasets/master/Datasets/wine.csv')
# Out:
# (pid=13700) Windows fatal exception: access violation
# (pid=13700)
# Wall time: 402 ms
#      Alcohol  Malic acid   Ash  Alcalinity of ash  Magnesium  Total phenols  \
# 0      14.23        1.71  2.43               15.6        127           2.80
# 1      13.20        1.78  2.14               11.2        100           2.65
# 2      13.16        2.36  2.67               18.6        101           2.80
# 3      14.37        1.95  2.50               16.8        113           3.85
# 4      13.24        2.59  2.87               21.0        118           2.80
# ..       ...         ...   ...                ...        ...            ...
# 173    13.71        5.65  2.45               20.5         95           1.68
# 174    13.40        3.91  2.48               23.0        102           1.80
# 175    13.27        4.28  2.26               20.0        120           1.59
# 176    13.17        2.59  2.37               20.0        120           1.65
# 177    14.13        4.10  2.74               24.5         96           2.05
#
#      Flavanoids  Nonflavanoid phenols  Proanthocyanins  Color intensity   Hue  \
# 0          3.06                  0.28             2.29             5.64  1.04
# 1          2.76                  0.26             1.28             4.38  1.05
# 2          3.24                  0.30             2.81             5.68  1.03
# 3          3.49                  0.24             2.18             7.80  0.86
# 4          2.69                  0.39             1.82             4.32  1.04
# ..          ...                   ...              ...              ...   ...
# 173        0.61                  0.52             1.06             7.70  0.64
# 174        0.75                  0.43             1.41             7.30  0.70
# 175        0.69                  0.43             1.35            10.20  0.59
# 176        0.68                  0.53             1.46             9.30  0.60
# 177        0.76                  0.56             1.35             9.20  0.61
#
#      OD280/OD315 of diluted wines  Proline  Class
# 0                            3.92     1065    one
# 1                            3.40     1050    one
# 2                            3.17     1185    one
# 3                            3.45     1480    one
# 4                            2.93      735    one
# ..                            ...      ...    ...
# 173                          1.74      740  three
# 174                          1.56      750  three
# 175                          1.56      835  three
# 176                          1.62      840  three
# 177                          1.60      560  three
#
# [178 rows x 14 columns]

# %%
# %%time
import modin.pandas as pd
pd.read_csv('https://raw.githubusercontent.com/MateLabs/Public-Datasets/master/Datasets/wine.csv')
# Out:
# UserWarning: Parameters provided defaulting to pandas implementation.
# To request implementation, send an email to feature_requests@modin.org.
# Wall time: 321 ms
#      Alcohol  Malic acid   Ash  Alcalinity of ash  Magnesium  Total phenols  \
# 0      14.23        1.71  2.43               15.6        127           2.80
# 1      13.20        1.78  2.14               11.2        100           2.65
# 2      13.16        2.36  2.67               18.6        101           2.80
# 3      14.37        1.95  2.50               16.8        113           3.85
# 4      13.24        2.59  2.87               21.0        118           2.80
# ..       ...         ...   ...                ...        ...            ...
# 173    13.71        5.65  2.45               20.5         95           1.68
# 174    13.40        3.91  2.48               23.0        102           1.80
# 175    13.27        4.28  2.26               20.0        120           1.59
# 176    13.17        2.59  2.37               20.0        120           1.65
# 177    14.13        4.10  2.74               24.5         96           2.05
#
#      Flavanoids  Nonflavanoid phenols  Proanthocyanins  Color intensity   Hue  \
# 0          3.06                  0.28             2.29             5.64  1.04
# 1          2.76                  0.26             1.28             4.38  1.05
# 2          3.24                  0.30             2.81             5.68  1.03
# 3          3.49                  0.24             2.18             7.80  0.86
# 4          2.69                  0.39             1.82             4.32  1.04
# ..          ...                   ...              ...              ...   ...
# 173        0.61                  0.52             1.06             7.70  0.64
# 174        0.75                  0.43             1.41             7.30  0.70
# 175        0.69                  0.43             1.35            10.20  0.59
# 176        0.68                  0.53             1.46             9.30  0.60
# 177        0.76                  0.56             1.35             9.20  0.61
#
#      OD280/OD315 of diluted wines  Proline  Class
# 0                            3.92     1065    one
# 1                            3.40     1050    one
# 2                            3.17     1185    one
# 3                            3.45     1480    one
# 4                            2.93      735    one
# ..                            ...      ...    ...
# 173                          1.74      740  three
# 174                          1.56      750  three
# 175                          1.56      835  three
# 176                          1.62      840  three
# 177                          1.60      560  three
#
# [178 rows x 14 columns]
